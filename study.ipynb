# %%
import pandas as pd
import torch
from torch import nn

# %%
df=pd.read_csv("data_set.csv")

# %%
df
# Out:
#                                                     text  ASSORTMENT  \
# 0      Маленький выбор товаров, хотелось бы ассортиме...           1
# 1                                                 Быстро           0
# 2                       Доставка постоянно задерживается           1
# 3                     Наценка и ассортимент расстраивают           1
# 4      Можно немного скинуть минимальную сумму заказа...           0
# ...                                                  ...         ...
# 13586  Задержка с доставкой не даете промокод на скид...           0
# 13587  Очень удобный формат сервиса и очень маленький...           1
# 13588  Сумма заказа почти всегда высокая, что зачасту...           1
# 13589  Часто, заказываю у вас молочную продукцию, при...           0
# 13590  Изначально подкупало то, что заказ от [NUM] ру...           1
#
#        PROMOTIONS  DELIVERY  PRICE  PRODUCTS_QUALITY  SUPPORT  \
# 0               1         0      0                 0        0
# ...

# %%
import numpy as np

# %%
indexes=df.index.to_list()

# %%
np.random.shuffle(indexes)

# %%
df.loc[indexes[:50]].to_csv("human_class.csv",index=False)

# %%
df_c=pd.read_csv("/home/sasha/Python/VKR/pytorch_bert/data_set.csv")
df_c.loc[1200:1500].to_csv("data_for_label.csv")
